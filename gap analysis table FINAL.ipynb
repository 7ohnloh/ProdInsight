# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ---------------------------------------------
# STEP 0: SETUP
# ---------------------------------------------
import pandas as pd
import numpy as np
import nltk
import string
import openai
from nltk import word_tokenize, pos_tag
from textblob import TextBlob
import matplotlib.pyplot as plt

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
from nltk.corpus import stopwords

# Set OpenAI API key
with open("/content/drive/MyDrive/Colab/DAI_AID/keys/openai_key.txt") as f:
    openai.api_key = f.read().strip()

# ---------------------------------------------
# STEP 1: CONFIG
# ---------------------------------------------
base_dir = "/content/drive/MyDrive/Colab/DAI_AID/extracted_data/cleaned_data"
files = [
    "airpodsmax_youtube_cleaned.csv",
    "sony_xm5_youtube_cleaned.csv",
    "sennheiser_momentum4_youtube_cleaned.csv",
    "airpodsmax_reddit_cleaned.csv",
    "sony_xm5_reddit_cleaned.csv",
    "sennheiser_momentum4_reddit_cleaned.csv",
]

filename_to_product = {
    "airpodsmax_youtube_cleaned.csv": "AirPods Max",
    "sony_xm5_youtube_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_youtube_cleaned.csv": "Momentum 4",
    "airpodsmax_reddit_cleaned.csv": "AirPods Max",
    "sony_xm5_reddit_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_reddit_cleaned.csv": "Momentum 4",
}

valid_specs = {
    "battery", "noise", "cancellation", "comfort", "sound", "fit", "build", "design",
    "durability", "case", "controls", "bluetooth", "microphone", "charging", "portability",
    "volume", "latency", "app", "touch", "connectivity", "price", "weight"
}

noise = set(stopwords.words("english")).union(
    {"airpods", "apple", "sony", "sennheiser", "bruh", "max", "xm5", "momentum", "lol", "bro"}
)

def get_sentiment(text):
    if not isinstance(text, str): return "Neutral"
    polarity = TextBlob(text).sentiment.polarity
    return "Positive" if polarity > 0.1 else "Negative" if polarity < -0.1 else "Neutral"

def extract_keywords(text):
    if not isinstance(text, str):
        return []
    tokens = word_tokenize(text.lower())
    tagged = pos_tag(tokens)
    return [w for w, t in tagged if t.startswith("NN") and w not in noise and w not in string.punctuation]


# ---------------------------------------------
# STEP 2: LOAD + PROCESS FILES
# ---------------------------------------------
all_rows = []
for file in files:
    path = f"{base_dir}/{file}"
    df = pd.read_csv(path)
    if 'cleaned_comment' not in df.columns:
        print(f"Skipping {file}")
        continue
    for _, row in df.iterrows():
        sent = get_sentiment(row['cleaned_comment'])
        kws = extract_keywords(row['cleaned_comment'])
        all_rows.append({
            "filename": file,
            "product": filename_to_product[file],
            "comment": row['cleaned_comment'],
            "sentiment": sent,
            "keywords": kws
        })

df_results = pd.DataFrame(all_rows)
df_results["sentiment_score"] = df_results["sentiment"].map({"Positive": 1, "Neutral": 0, "Negative": -1})

# ---------------------------------------------
# STEP 3: GAP ANALYSIS
# ---------------------------------------------
df_exploded = df_results.explode("keywords")
df_exploded["keywords"] = df_exploded["keywords"].str.strip().str.lower()
df_specs = df_exploded[df_exploded["keywords"].isin(valid_specs)].copy()

pivot_df = df_specs.groupby(["keywords", "product"])["sentiment_score"].mean().reset_index()
pivot_table = pivot_df.pivot(index="keywords", columns="product", values="sentiment_score").fillna(0)

pivot_table["CompetitorAvg"] = pivot_table[["Sony XM5", "Momentum 4"]].mean(axis=1)
pivot_table["Gap_vs_Competitors"] = pivot_table["CompetitorAvg"] - pivot_table["AirPods Max"]
pivot_table["Underperforming"] = pivot_table["Gap_vs_Competitors"] > 0.2

price_map = {"AirPods Max": 549, "Sony XM5": 399, "Momentum 4": 379}
for product in price_map:
    pivot_table[f"{product}_P2P"] = pivot_table[product] / price_map[product]

# Display gap table
gap_cols = [
    "AirPods Max", "Sony XM5", "Momentum 4",
    "CompetitorAvg", "Gap_vs_Competitors",
    "Underperforming",
    "AirPods Max_P2P", "Sony XM5_P2P", "Momentum 4_P2P"
]
print("\n=== GAP ANALYSIS TABLE ===")
display(pivot_table[gap_cols].sort_values("Gap_vs_Competitors", ascending=False))

# ---------------------------------------------
# STEP 4: DESIGN OPPORTUNITY EXPLAINER (GPT)
# ---------------------------------------------
underperf = pivot_table[pivot_table["Underperforming"]].index.tolist()
comments_by_feature = df_specs[
    (df_specs["product"] == "AirPods Max") &
    (df_specs["keywords"].isin(underperf))
].groupby("keywords")["comment"].apply(lambda x: "\n".join(x.dropna().unique()[:10]))

def gpt_design_opportunity(feature, comments):
    prompt = f"""
You are a product strategist. Users gave negative feedback on the **"{feature}"** of the AirPods Max.
Here are sample complaints:
{comments}

Based on these:
1. Identify specific issues
2. Translate to measurable design specs
3. Suggest improvements
4. Estimate potential impact (sales, brand, ROI)
5. List all insights clearly in bullet points.
"""
    try:
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# Generate output
for feature, sample_comments in comments_by_feature.items():
    print(f"\n\n===== DESIGN OPPORTUNITY: {feature.upper()} =====")
    print(gpt_design_opportunity(feature, sample_comments))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# === GAP ANALYSIS TABLE ===
# product       AirPods Max  Sony XM5  Momentum 4  CompetitorAvg  \
# keywords
# microphone       0.333333  0.473684    0.875000       0.674342
# fit              0.571429  0.851852    0.846154       0.849003
# build            0.529412  0.800000    0.777778       0.788889
# latency          0.161290  0.318182    0.500000       0.409091
# comfort          0.555556  0.742857    0.782609       0.762733
# case             0.403587  0.471649    0.620253       0.545951
# battery          0.475410  0.703448    0.523077       0.613263
# weight           0.378378  0.666667    0.363636       0.515152
# price            0.481928  0.579545    0.592105       0.585825
# portability      0.714286  0.633333    1.000000       0.816667
# volume           0.433333  0.513889    0.458333       0.486111
# design           0.410714  0.428571    0.468085       0.448328
# app              0.384615  0.367347    0.464286       0.415816
# noise            0.596330  0.524621    0.676471       0.600546
# sound            0.840909  0.790274    0.857143       0.823708
# connectivity     0.416667  0.454545    0.300000       0.377273
# cancellation     0.791667  0.554688    0.923077       0.738882
# charging         1.000000  0.833333    1.000000       0.916667
# controls         0.400000  0.257143    0.352941       0.305042
# touch            0.600000  0.512195    0.360000       0.436098
# durability       0.750000  0.567568    0.571429       0.569498
# bluetooth        0.550000  0.452381    0.260870       0.356625
#
# product       Gap_vs_Competitors  Underperforming  AirPods Max_P2P  \
# keywords
# microphone              0.341009             True         0.000607
# fit                     0.277574             True         0.001041
# build                   0.259477             True         0.000964
# latency                 0.247801             True         0.000294
# comfort                 0.207177             True         0.001012
# case                    0.142364            False         0.000735
# battery                 0.137853            False         0.000866
# weight                  0.136773            False         0.000689
# price                   0.103898            False         0.000878
# portability             0.102381            False         0.001301
# volume                  0.052778            False         0.000789
# design                  0.037614            False         0.000748
# app                     0.031201            False         0.000701
# noise                   0.004216            False         0.001086
# sound                  -0.017201            False         0.001532
# connectivity           -0.039394            False         0.000759
# cancellation           -0.052784            False         0.001442
# charging               -0.083333            False         0.001821
# controls               -0.094958            False         0.000729
# touch                  -0.163902            False         0.001093
# durability             -0.180502            False         0.001366
# bluetooth              -0.193375            False         0.001002
#
# product       Sony XM5_P2P  Momentum 4_P2P
# keywords
# microphone        0.001187        0.002309
# fit               0.002135        0.002233
# build             0.002005        0.002052
# latency           0.000797        0.001319
# comfort           0.001862        0.002065
# case              0.001182        0.001637
# battery           0.001763        0.001380
# weight            0.001671        0.000959
# price             0.001452        0.001562
# portability       0.001587        0.002639
# volume            0.001288        0.001209
# design            0.001074        0.001235
# app               0.000921        0.001225
# noise             0.001315        0.001785
# sound             0.001981        0.002262
# connectivity      0.001139        0.000792
# cancellation      0.001390        0.002436
# charging          0.002089        0.002639
# controls          0.000644        0.000931
# touch             0.001284        0.000950
# durability        0.001422        0.001508
# bluetooth         0.001134        0.000688
# ===== DESIGN OPPORTUNITY: BUILD =====
# Specific issues:
# - Comfort issues such as ear heating up and uncomfortable pressure after extended use
# - Durability concerns including condensation buildup and hinge noise
# - Portability issues with the Smart Case not meeting expectations
# - Build quality comparisons with other brands such as Beats and concerns about plastic build
# - Fit issues with the headphones sliding around on the head with movement
#
# Measurable design specs:
# - Improve earpad material to prevent overheating and discomfort
# - Address condensation buildup issue and ensure hinge noise is eliminated
# - Redesign Smart Case for better functionality and protection
# - Enhance build quality with stronger materials and better construction
# - Improve headband design for better fit and stability during movement
#
# Improvements:
# - Use more breathable materials for earpads to prevent overheating
# - Implement better sealant to prevent condensation buildup
# - Reinforce hinge mechanism to reduce noise and improve longevity
# - Redesign Smart Case for better protection and ease of use
# - Enhance overall build quality with premium materials and construction
# - Improve headband design for better fit and stability during movement
#
# Potential impact:
# - Improved comfort and durability can lead to increased customer satisfaction and loyalty
# - Enhanced portability features can attract more on-the-go users
# - Better build quality can enhance brand reputation and differentiate from competitors
# - Addressing fit issues can improve overall user experience and usability
#
# Insights:
# - Customers value comfort, durability, and portability in headphones
# - Build quality comparisons with other brands can impact purchasing decisions
# - Fit and stability are important factors for user satisfaction
# - Fashionable design can attract a specific demographic of customers
# - Addressing specific issues can lead to a more competitive product in the market.
#
#
# ===== DESIGN OPPORTUNITY: COMFORT =====
# Specific issues:
# - Weight and discomfort after extended use
# - Headband causing itchiness and discomfort
# - Mesh headband stretching and deteriorating over time
# - Ear cups getting dirty and needing frequent cleaning
# - Headphones causing headaches and jaw pain
# - Transparency mode interfering with personal singing experience
# - Connectivity issues and need for frequent cleaning
#
# Measurable design specs:
# - Reduce weight of AirPods Max
# - Improve headband design for better comfort and durability
# - Provide additional ear cup options, such as leather
# - Enhance mesh headband longevity and long-term comfort
# - Implement adaptive transparency feature
# - Improve mic quality for clearer calls
# - Upgrade to Bluetooth 5.3 for better connectivity
#
# Potential improvements:
# - Increased comfort and reduced discomfort for users
# - Enhanced durability and longevity of the product
# - Improved user experience with better connectivity and sound quality
# - Higher customer satisfaction and loyalty
# - Potential increase in sales and positive brand reputation
#
# Estimated impact:
# - Increased sales due to improved comfort and durability
# - Higher customer satisfaction leading to repeat purchases and positive word-of-mouth
# - Stronger brand reputation as a result of addressing user feedback
# - Potential return on investment through improved product design and features
#
# Insights:
# - Weight and discomfort are significant issues for users
# - Headband design and material are key factors in comfort and durability
# - Connectivity issues and cleanliness concerns should be addressed
# - Transparency mode should be improved for better user experience
# - Upgrading to Bluetooth 5.3 can enhance connectivity and overall performance
#
#
# ===== DESIGN OPPORTUNITY: FIT =====
# Specific Issues:
# - High price point
# - Lighting connector for charging
# - Lack of water resistance for gym use
# - Condensation issues after extended use
# - Uncomfortable fit for some users, especially with glasses
# - Heavy weight
# - Case not providing adequate protection
# - Limited compatibility with non-Apple devices
# - Limited usage for those with larger heads
#
# Measurable Design Specs:
# - Lower price point to increase affordability
# - Implement USB-C charging for convenience
# - Improve water resistance for gym use
# - Address condensation issues to improve durability
# - Enhance comfort and fit for users, especially those with glasses
# - Reduce weight of AirPods Max
# - Improve case design for better protection
# - Increase compatibility with non-Apple devices
#
# Improvements:
# - Lower price point to make AirPods Max more accessible
# - Switch to USB-C charging for convenience and wider compatibility
# - Enhance water resistance for gym use
# - Address condensation issues to improve product durability
# - Improve comfort and fit for users, especially those with glasses
# - Reduce weight of AirPods Max for better comfort during extended use
# - Redesign case for better protection of AirPods Max
# - Increase compatibility with non-Apple devices
#
# Potential Impact:
# - Increase in sales due to lower price point and improved features
# - Positive impact on brand reputation for addressing user feedback
# - Higher ROI from increased customer satisfaction and loyalty
#
# Insights:
# - Users find the high price point of AirPods Max to be a barrier to purchase
# - Charging with a lighting connector is inconvenient for some users
# - Water resistance and durability are important factors for gym use
# - Comfort and fit issues, especially with glasses, need to be addressed
# - Weight and case design are areas for improvement
# - Compatibility with non-Apple devices should be expanded to reach a wider audience
# - Addressing these issues can lead to increased sales, brand loyalty, and ROI
#
#
# ===== DESIGN OPPORTUNITY: LATENCY =====
# 1. Specific issues:
# - Users are experiencing noticeable latency when using the AirPods Max for real-time activities such as audio/video editing and gaming.
# - Users are confused about the inclusion of ultra-low latency in the upcoming firmware update for the USB-C models.
# - Some users feel that wired performance on the Lightning models is instantaneous, but there are concerns about the potential limitations of the ports.
#
# 2. Measurable design specs:
# - Target latency reduction to below a certain threshold (e.g., 20ms) for real-time activities.
# - Clearly communicate the improvements in latency with the firmware update for USB-C models.
# - Conduct thorough testing to ensure that wired performance is optimized and instantaneous on all models.
#
# 3. Suggestions for improvements:
# - Implement optimizations in the firmware update to reduce latency for real-time activities.
# - Clarify the benefits of ultra-low latency in the marketing materials and product descriptions.
# - Consider hardware enhancements to improve wired performance on all models.
#
# 4. Estimated potential impact:
# - Sales: Improving latency and clarifying features could attract more customers who prioritize real-time activities.
# - Brand: Clear communication and effective improvements could enhance the brand's reputation for quality and innovation.
# - ROI: Investing in latency improvements and clear messaging could lead to increased customer satisfaction and loyalty, resulting in a positive return on investment.
#
# 5. Insights:
# - Latency is a significant issue for users engaged in real-time activities such as gaming and audio/video editing.
# - Clear communication about features and updates is essential for user understanding and satisfaction.
# - Optimizing both wireless and wired performance is crucial for meeting user expectations and maintaining a competitive edge in the market.
#
#
# ===== DESIGN OPPORTUNITY: MICROPHONE =====
# Specific issues:
# - Users are complaining about the poor microphone quality of the AirPods Max compared to other products like the AirPods Pro 2 and qc35.
# - Users are also confused about the functionality of the microphone in different scenarios.
# - Users are disappointed with Apple's marketing language, specifically regarding the term "bidirectional."
#
# Measurable design specs:
# - Improve microphone quality to match or exceed competitors like AirPods Pro 2 and qc35.
# - Clarify the functionality of the microphone in different scenarios for user understanding.
# - Address confusion around the term "bidirectional" in Apple's marketing.
#
# Suggestions for improvements:
# - Enhance the microphone technology to improve sound quality during calls.
# - Provide clear and detailed information in marketing materials about the microphone functionality.
# - Update product documentation to explain technical terms like "bidirectional" in a user-friendly way.
#
# Potential impact:
# - Improving the microphone quality can lead to increased sales as users will be more satisfied with the product for daily use, especially for meetings.
# - Clear communication about microphone functionality can enhance the overall user experience and improve brand perception.
# - Clarifying technical terms can reduce user confusion and frustration, leading to a more positive perception of the product and brand.
#
# Insights:
# - The microphone quality of the AirPods Max is a significant pain point for users and needs to be addressed for better user satisfaction.
# - Clear and transparent communication about product features is crucial for user understanding and satisfaction.
# - Addressing technical terminology and user confusion can improve the overall user experience and brand perception.

# %%
THIS IS WHAT WE ARE USING
# ---------------------------------------------
# STEP 0: SETUP
# ---------------------------------------------
import pandas as pd
import numpy as np
import nltk
import string
import openai
from nltk import word_tokenize, pos_tag
from textblob import TextBlob
import matplotlib.pyplot as plt

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
from nltk.corpus import stopwords

# Set OpenAI API key
with open("/content/drive/MyDrive/Colab/DAI_AID/keys/openai_key.txt") as f:
    openai.api_key = f.read().strip()

# ---------------------------------------------
# STEP 1: CONFIG
# ---------------------------------------------
base_dir = "/content/drive/MyDrive/Colab/DAI_AID/extracted_data/cleaned_data"
files = [
    "airpodsmax_youtube_cleaned.csv",
    "sony_xm5_youtube_cleaned.csv",
    "sennheiser_momentum4_youtube_cleaned.csv",
    "airpodsmax_reddit_cleaned.csv",
    "sony_xm5_reddit_cleaned.csv",
    "sennheiser_momentum4_reddit_cleaned.csv",
]

filename_to_product = {
    "airpodsmax_youtube_cleaned.csv": "AirPods Max",
    "sony_xm5_youtube_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_youtube_cleaned.csv": "Momentum 4",
    "airpodsmax_reddit_cleaned.csv": "AirPods Max",
    "sony_xm5_reddit_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_reddit_cleaned.csv": "Momentum 4",
}

valid_specs = {
    "battery", "noise", "cancellation", "comfort", "sound", "fit", "build", "design",
    "durability", "case", "controls", "bluetooth", "microphone", "charging", "portability",
    "volume", "latency", "app", "touch", "connectivity", "price", "weight"
}

noise = set(stopwords.words("english")).union(
    {"airpods", "apple", "sony", "sennheiser", "bruh", "max", "xm5", "momentum", "lol", "bro"}
)

def get_sentiment(text):
    if not isinstance(text, str): return "Neutral"
    polarity = TextBlob(text).sentiment.polarity
    return "Positive" if polarity > 0.1 else "Negative" if polarity < -0.1 else "Neutral"

def extract_keywords(text):
    if not isinstance(text, str):
        return []
    tokens = word_tokenize(text.lower())
    tagged = pos_tag(tokens)
    return [w for w, t in tagged if t.startswith("NN") and w not in noise and w not in string.punctuation]


# ---------------------------------------------
# STEP 2: LOAD + PROCESS FILES
# ---------------------------------------------
all_rows = []
for file in files:
    path = f"{base_dir}/{file}"
    df = pd.read_csv(path)
    if 'cleaned_comment' not in df.columns:
        print(f"Skipping {file}")
        continue
    for _, row in df.iterrows():
        sent = get_sentiment(row['cleaned_comment'])
        kws = extract_keywords(row['cleaned_comment'])
        all_rows.append({
            "filename": file,
            "product": filename_to_product[file],
            "comment": row['cleaned_comment'],
            "sentiment": sent,
            "keywords": kws
        })

df_results = pd.DataFrame(all_rows)
df_results["sentiment_score"] = df_results["sentiment"].map({"Positive": 1, "Neutral": 0, "Negative": -1})

# ---------------------------------------------
# STEP 3: GAP ANALYSIS
# ---------------------------------------------
df_exploded = df_results.explode("keywords")
df_exploded["keywords"] = df_exploded["keywords"].str.strip().str.lower()
df_specs = df_exploded[df_exploded["keywords"].isin(valid_specs)].copy()

pivot_df = df_specs.groupby(["keywords", "product"])["sentiment_score"].mean().reset_index()
pivot_table = pivot_df.pivot(index="keywords", columns="product", values="sentiment_score").fillna(0)

pivot_table["CompetitorAvg"] = pivot_table[["Sony XM5", "Momentum 4"]].mean(axis=1)
pivot_table["Gap_vs_Competitors"] = pivot_table["CompetitorAvg"] - pivot_table["AirPods Max"]
pivot_table["Underperforming"] = pivot_table["Gap_vs_Competitors"] > 0.2

price_map = {"AirPods Max": 549, "Sony XM5": 399, "Momentum 4": 379}
for product in price_map:
    pivot_table[f"{product}_P2P"] = pivot_table[product] / price_map[product]

# Display gap table
gap_cols = [
    "AirPods Max", "Sony XM5", "Momentum 4",
    "CompetitorAvg", "Gap_vs_Competitors",
    "Underperforming",
    "AirPods Max_P2P", "Sony XM5_P2P", "Momentum 4_P2P"
]
print("\n=== GAP ANALYSIS TABLE ===")
display(pivot_table[gap_cols].sort_values("Gap_vs_Competitors", ascending=False))

# ---------------------------------------------
# STEP 4: DESIGN OPPORTUNITY INSIGHTS (TOP GAP ONLY)
# ---------------------------------------------
# Sort underperforming specs by highest gap
N = 5  # adjust how many top underperforming specs to analyze
top_underperf = (
    pivot_table[pivot_table["Underperforming"]]
    .sort_values("Gap_vs_Competitors", ascending=False)
    .head(N)
    .index
    .tolist()
)

# Get AirPods Max comments for those specs
comments_by_feature = df_specs[
    (df_specs["product"] == "AirPods Max") &
    (df_specs["keywords"].isin(top_underperf))
].groupby("keywords")["comment"].apply(lambda x: "\n".join(x.dropna().unique()[:10]))

def gpt_design_opportunity(feature, comments):
    prompt = f"""
You are a product strategist. Users gave negative feedback on the **"{feature}"** of the AirPods Max.
Here are sample complaints:
{comments}

Based on these:
1. Identify specific issues
2. Translate to measurable design specs
3. Suggest improvements
4. Estimate potential impact (sales, brand, ROI)
5. List all insights clearly in bullet points.
"""
    try:
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# Generate insights for top N underperforming specs
print(f"\n=== GPT DESIGN OPPORTUNITY ANALYSIS (TOP {N} FEATURES) ===")
for feature, sample_comments in comments_by_feature.items():
    print(f"\n\n===== DESIGN OPPORTUNITY: {feature.upper()} =====")
    print(gpt_design_opportunity(feature, sample_comments))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# === GAP ANALYSIS TABLE ===
# product       AirPods Max  Sony XM5  Momentum 4  CompetitorAvg  \
# keywords
# microphone       0.333333  0.473684    0.875000       0.674342
# fit              0.571429  0.851852    0.846154       0.849003
# build            0.529412  0.800000    0.777778       0.788889
# latency          0.161290  0.318182    0.500000       0.409091
# comfort          0.555556  0.742857    0.782609       0.762733
# case             0.403587  0.471649    0.620253       0.545951
# battery          0.475410  0.703448    0.523077       0.613263
# weight           0.378378  0.666667    0.363636       0.515152
# price            0.481928  0.579545    0.592105       0.585825
# portability      0.714286  0.633333    1.000000       0.816667
# volume           0.433333  0.513889    0.458333       0.486111
# design           0.410714  0.428571    0.468085       0.448328
# app              0.384615  0.367347    0.464286       0.415816
# noise            0.596330  0.524621    0.676471       0.600546
# sound            0.840909  0.790274    0.857143       0.823708
# connectivity     0.416667  0.454545    0.300000       0.377273
# cancellation     0.791667  0.554688    0.923077       0.738882
# charging         1.000000  0.833333    1.000000       0.916667
# controls         0.400000  0.257143    0.352941       0.305042
# touch            0.600000  0.512195    0.360000       0.436098
# durability       0.750000  0.567568    0.571429       0.569498
# bluetooth        0.550000  0.452381    0.260870       0.356625
#
# product       Gap_vs_Competitors  Underperforming  AirPods Max_P2P  \
# keywords
# microphone              0.341009             True         0.000607
# fit                     0.277574             True         0.001041
# build                   0.259477             True         0.000964
# latency                 0.247801             True         0.000294
# comfort                 0.207177             True         0.001012
# case                    0.142364            False         0.000735
# battery                 0.137853            False         0.000866
# weight                  0.136773            False         0.000689
# price                   0.103898            False         0.000878
# portability             0.102381            False         0.001301
# volume                  0.052778            False         0.000789
# design                  0.037614            False         0.000748
# app                     0.031201            False         0.000701
# noise                   0.004216            False         0.001086
# sound                  -0.017201            False         0.001532
# connectivity           -0.039394            False         0.000759
# cancellation           -0.052784            False         0.001442
# charging               -0.083333            False         0.001821
# controls               -0.094958            False         0.000729
# touch                  -0.163902            False         0.001093
# durability             -0.180502            False         0.001366
# bluetooth              -0.193375            False         0.001002
#
# product       Sony XM5_P2P  Momentum 4_P2P
# keywords
# microphone        0.001187        0.002309
# fit               0.002135        0.002233
# build             0.002005        0.002052
# latency           0.000797        0.001319
# comfort           0.001862        0.002065
# case              0.001182        0.001637
# battery           0.001763        0.001380
# weight            0.001671        0.000959
# price             0.001452        0.001562
# portability       0.001587        0.002639
# volume            0.001288        0.001209
# design            0.001074        0.001235
# app               0.000921        0.001225
# noise             0.001315        0.001785
# sound             0.001981        0.002262
# connectivity      0.001139        0.000792
# cancellation      0.001390        0.002436
# charging          0.002089        0.002639
# controls          0.000644        0.000931
# touch             0.001284        0.000950
# durability        0.001422        0.001508
# bluetooth         0.001134        0.000688
# === GPT DESIGN OPPORTUNITY ANALYSIS (TOP 5 FEATURES) ===
#
#
# ===== DESIGN OPPORTUNITY: BUILD =====
# 1. Specific issues:
# - Complaints about the build quality of the AirPods Max, including issues with the case, ear pad comfort, durability, portability, and fit on the head.
# - Comparison to Beats headphones in terms of build quality, sound signature, and affordability.
# - Concerns about the durability and reliability of Beats headphones.
# - Desire for lightweight design with sturdy build quality.
# - Preference for replaceable ear pads and design elements from other headphone brands like Sennheiser and Master & Dynamic.
#
# 2. Measurable design specs:
# - Ear pad comfort rating of 7.5/10, with a goal to improve comfort for extended wear.
# - Durability and build rating of 9.0/10, with a focus on addressing condensation buildup, hinge noise, and overall sturdiness.
# - Portability rating of 6/10, with a need to improve the functionality and user experience of the Smart Case.
# - Sound quality rating of 8.5/10, with potential improvements in detail capture and tuning for different genres.
# - Fit on the head, sliding, and movement issues, with a goal to enhance stability and adjustability for different head sizes.
# - Fashionability and minimalistic design appeal, with a focus on maintaining or enhancing these aspects.
#
# 3. Suggestions for improvements:
# - Address condensation buildup issue to improve durability.
# - Enhance comfort for extended wear by improving ear pad materials or design.
# - Revise the Smart Case design for better portability and protection.
# - Improve stability and fit on the head for active use.
# - Consider incorporating features from other headphone brands, such as replaceable ear pads or design elements from Sennheiser and Master & Dynamic.
#
# 4. Potential impact:
# - Improvements in build quality and comfort could lead to increased sales and customer satisfaction.
# - Enhancing durability and reliability could improve the brand's reputation and loyalty among users.
# - Addressing fit and stability issues could attract more active users and expand the target market.
# - Incorporating design elements from other reputable headphone brands could enhance the overall appeal and market positioning of the AirPods Max.
#
# 5. Insights:
# - Users have mixed feelings about the build quality of the AirPods Max, with some praising its durability and design, while others express concerns about comfort and durability issues.
# - Comparisons to Beats headphones highlight the importance of balancing affordability, sound quality, and build quality in headphone design.
# - Desire for lightweight design with sturdy build quality suggests a need for innovative materials and construction techniques in headphone manufacturing.
# - Incorporating user feedback on comfort, durability, portability, and fit could lead to significant improvements in the overall user experience and market competitiveness of the AirPods Max.
#
#
# ===== DESIGN OPPORTUNITY: COMFORT =====
# Specific issues:
# 1. Weight and discomfort after prolonged use
# 2. Headband causing pressure and discomfort
# 3. Mesh headband causing itching and dandruff
# 4. Ear cups getting dirty and potentially causing discomfort
# 5. Connectivity issues and need for frequent cleaning
#
# Measurable design specs:
# 1. Reduce weight of AirPods Max
# 2. Redesign headband for better pressure distribution
# 3. Use a different material for headband to prevent itching and dandruff
# 4. Provide easily replaceable or washable ear cups
# 5. Improve connectivity and reduce need for frequent cleaning
#
# Improvements:
# 1. Lighter weight materials for overall comfort
# 2. Redesigned headband for better pressure distribution
# 3. Use of a more comfortable material for headband
# 4. Easy to clean or replaceable ear cups
# 5. Enhanced connectivity features to reduce maintenance
#
# Potential impact:
# 1. Increase in sales due to improved comfort and user experience
# 2. Positive impact on brand reputation for addressing user feedback
# 3. Potential increase in ROI from higher customer satisfaction and loyalty
#
# Insights:
# - Weight and discomfort are major issues for users, affecting prolonged use
# - Headband design and material causing pressure and discomfort for some users
# - Mesh headband causing itching and dandruff, impacting comfort
# - Connectivity issues and need for frequent cleaning are additional pain points for users
# - Addressing these issues can lead to improved sales, brand reputation, and ROI
#
#
# ===== DESIGN OPPORTUNITY: FIT =====
# 1. Specific issues:
# - High price point
# - Lack of water resistance for gym use
# - Condensation issue leading to malfunction after 1.5 years
# - Uncomfortable fit for some users, especially with glasses
# - Heavy weight
# - Case design not providing adequate protection
# - Comparison to other competitors like Sony WH-1000xm5 and B&W PX8
#
# 2. Measurable design specs:
# - Reduced weight for improved comfort during long usage
# - Improved fit for users with glasses
# - Enhanced water resistance for gym use
# - Redesigned case for better protection
# - Lower price point to be more competitive with other brands
#
# 3. Suggestions for improvements:
# - Offer different sizes or adjustable headband for better fit on various head sizes
# - Improve materials to prevent condensation issues
# - Design a more protective case that also includes a power button
# - Consider offering a lower-priced version with fewer features for budget-conscious consumers
#
# 4. Estimated potential impact:
# - Increased sales from addressing key issues such as fit, weight, and price
# - Improved brand perception by listening to customer feedback and making necessary improvements
# - Higher ROI from increased customer satisfaction and loyalty
#
# 5. Insights:
# - There is a demand for more affordable options that still offer high-quality sound and features
# - Water resistance and durability are important factors for users who want to use headphones during physical activities
# - Comfort and fit are crucial for long-term usage, especially for users with glasses or larger head sizes
# - Competitor comparison highlights areas where AirPods Max can improve to stay competitive in the market.
#
#
# ===== DESIGN OPPORTUNITY: LATENCY =====
# 1. Specific issues:
#    - Users are experiencing noticeable latency when using the AirPods Max for real-time activities such as audio/video editing and gaming.
#    - The lightning models already had lossless audio but lacked ultra-low latency.
#    - Users are confused about the inclusion of ultra-low latency in the upcoming firmware update for the USB-C models.
#
# 2. Measurable design specs:
#    - Latency should be reduced to a minimum level that is imperceptible to users during real-time activities.
#    - Lossless audio should be maintained or improved upon in the firmware update for both lightning and USB-C models.
#    - Clear communication and education for users on the benefits and improvements brought by the firmware update.
#
# 3. Suggestions for improvements:
#    - Implement a firmware update that addresses the latency issues for both lightning and USB-C models.
#    - Provide clear documentation and communication on the improvements in latency and lossless audio with the firmware update.
#    - Consider further optimizing the DAC performance to enhance wired performance and reduce latency.
#
# 4. Potential impact:
#    - Sales: Improving latency and providing lossless audio could attract more customers who prioritize real-time activities and audio quality.
#    - Brand: Addressing user feedback and improving the overall experience with the AirPods Max could enhance brand reputation and customer satisfaction.
#    - ROI: Investing in firmware updates and improvements could lead to increased sales and customer loyalty, resulting in a positive return on investment.
#
# 5. Insights:
#    - Users value low latency and lossless audio for real-time activities such as gaming and audio/video editing.
#    - Clear communication and education are crucial in ensuring users understand the benefits and improvements brought by firmware updates.
#    - Optimizing DAC performance can further enhance wired performance and reduce latency for a seamless user experience.
#
#
# ===== DESIGN OPPORTUNITY: MICROPHONE =====
# 1. Specific issues:
# - Users are complaining about the poor microphone quality of the AirPods Max compared to other products like AirPods Pro 2 or Bose QC35.
# - Some users find the microphone to be "absolute garbage" and not suitable for daily use, especially for meetings.
# - Users are seeking more information on the microphone quality in reviews.
# - There is confusion around the term "bidirectional" in Apple's marketing, specifically regarding audio output and microphone input.
#
# 2. Measurable design specs:
# - Improve microphone quality to match or exceed competitors like AirPods Pro 2 and Bose QC35.
# - Clarify and enhance the microphone performance in product reviews.
# - Provide clear and accurate information on the functionality of the "bidirectional" feature in marketing materials.
#
# 3. Suggestions for improvements:
# - Upgrade the microphone technology in the AirPods Max to deliver clearer and more reliable audio during calls.
# - Conduct thorough testing and optimization of the microphone to ensure it meets or exceeds industry standards.
# - Provide detailed information on the microphone quality in product descriptions and reviews to set accurate expectations for users.
# - Clarify the functionality of the "bidirectional" feature in marketing materials to avoid confusion and misinterpretation.
#
# 4. Potential impact:
# - Improving the microphone quality could lead to increased sales as users value clear communication during calls.
# - Enhancing the microphone performance may improve the overall brand reputation for Apple in the audio accessories market.
# - Clear and accurate information on the microphone functionality could reduce customer confusion and improve user satisfaction, leading to higher customer retention and loyalty.
# - Addressing the microphone issues and providing accurate marketing information may result in a positive return on investment by attracting more customers and boosting product sales.
#
# 5. Insights:
# - The microphone quality of the AirPods Max is a significant pain point for users, impacting their overall satisfaction with the product.
# - Clear and detailed information on the microphone performance is crucial for setting accurate expectations and addressing user concerns.
# - Improving the microphone technology and communication around its functionality can have a positive impact on sales, brand reputation, and ROI for Apple.

# %% [markdown]
# ---
#
# ## 🔍 Full Breakdown of the Code
#
# ---
#
# ### **STEP 0: SETUP**
# - **Imports** required libraries like `pandas`, `openai`, `nltk`, `textblob`, etc.
# - Downloads NLTK resources needed for tokenization and POS tagging.
# - Reads your OpenAI API key securely from Drive.
#
# ---
#
# ### **STEP 1: CONFIG**
# - Defines the **list of cleaned CSV files** from Reddit and YouTube.
# - Maps each file to its **corresponding product** (`AirPods Max`, `Sony XM5`, or `Momentum 4`).
# - Defines a **set of valid specs/features** to focus on (e.g., battery, weight, price).
# - Builds a **noise filter** that removes common stopwords and irrelevant slang or brand words from the keyword extraction step.
#
# ---
#
# ### **STEP 2: LOAD + PROCESS FILES**
# - Iterates through each cleaned CSV file.
# - For each comment:
#   - Performs **sentiment analysis** using TextBlob (`Positive`, `Neutral`, `Negative`).
#   - Performs **keyword extraction**, keeping only nouns that match valid specs and are not in the noise list.
# - Results are stored in a single unified dataframe `df_results`.
#
# ---
#
# ### **STEP 3: GAP ANALYSIS**
# - Explodes keywords so each row has one keyword per comment.
# - Filters to retain only keywords that are valid specs.
# - **Groups sentiment scores** by `product` and `feature`.
# - Creates a **pivot table** showing average sentiment score per spec per product.
# - Computes:
#   - **Competitor Average** = average of Sony XM5 and Momentum 4 scores
#   - **Gap_vs_Competitors** = how much worse AirPods Max performs relative to the competition
#   - **Underperforming = True** if gap exceeds 0.2
# - Adds **price-to-performance (P2P)** scores by dividing sentiment by product price.
#
# ---
#
# ### **STEP 4: GPT DESIGN OPPORTUNITIES**
# - Picks **top N underperforming specs** based on the highest `Gap_vs_Competitors`.
# - For each one, collects up to 10 real comments mentioning that spec.
# - Feeds those into GPT-3.5-turbo via OpenAI API with a detailed prompt asking for:
#   - User problems
#   - Measurable design issues
#   - Suggestions
#   - ROI implications
# - GPT response is printed as a **feature-specific design insight block**.
#
# ---
#
# ## 📊 Explanation for Use in Project Report
#
# ---
#
# ### **Objective:**
# To identify actionable design opportunities for the AirPods Max by analyzing real user feedback from Reddit and YouTube and benchmarking it against top competitors (Sony XM5, Sennheiser Momentum 4).
#
# ---
#
# ### **Why This Analysis Matters:**
#
# 1. **Grounds design decisions in user sentiment:**
#    - Instead of relying on intuition or vague reviews, we quantify how users feel about specific product features (e.g., weight, comfort, battery life).
#    - This allows product teams to prioritize real pain points.
#
# 2. **Benchmarks against market leaders:**
#    - By comparing AirPods Max to Sony and Sennheiser, we identify where the product **underperforms in the eyes of users**, even though it has a higher price point.
#
# 3. **Pinpoints features with measurable gaps:**
#    - The “Gap_vs_Competitors” metric directly highlights features where sentiment is significantly more negative for AirPods Max than its competitors.
#
# 4. **Justifies ROI-driven redesigns:**
#    - Using GPT, we translate complaints into **design requirements** (e.g., “uncomfortable” → adjust headband pressure).
#    - Each suggestion is accompanied by potential **business impact** (e.g., retention, revenue, or brand perception).
#
# 5. **Makes funding decisions easier:**
#    - If a design flaw (e.g., “heavy build”) appears across hundreds of comments and GPT suggests a fix, the PM can argue:
#      > “Spending $2k on redesigning this component could lead to a significant boost in user satisfaction and market competitiveness.”
#
# ---
#
# ### **How This Helps a Product Manager:**
# | Value Added | Description |
# |-------------|-------------|
# | **Prioritization** | Focus on specs that matter most to users and where the product underdelivers. |
# | **Cost-benefit clarity** | Identify fixes that bring high sentiment improvement with minimal cost (via P2P and GPT analysis). |
# | **Evidence-based justification** | Provides hard data and real quotes to justify design and engineering changes. |
# | **Strategic alignment** | Aligns product roadmap with competitive intelligence and user expectations. |
#
# ---
#
# ### 🔚 Final Note
# This analysis transforms scattered social media feedback into **actionable intelligence** for product, design, and business teams — making it easier to decide **where to invest, what to fix, and how to win back market edge**.
#
# ---

# %%
# ---------------------------------------------
# SETUP
# ---------------------------------------------
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import matplotlib.pyplot as plt
import re
from textblob import TextBlob

# ---------------------------------------------
# LOAD CLEANED DATA
# ---------------------------------------------
base = "/content/drive/MyDrive/Colab/DAI_AID/extracted_data/cleaned_data"

df_airpods = pd.concat([
    pd.read_csv(f"{base}/airpodsmax_youtube_cleaned.csv"),
    pd.read_csv(f"{base}/airpodsmax_reddit_cleaned.csv")
])
df_sony = pd.concat([
    pd.read_csv(f"{base}/sony_xm5_youtube_cleaned.csv"),
    pd.read_csv(f"{base}/sony_xm5_reddit_cleaned.csv")
])
df_senn = pd.concat([
    pd.read_csv(f"{base}/sennheiser_momentum4_youtube_cleaned.csv"),
    pd.read_csv(f"{base}/sennheiser_momentum4_reddit_cleaned.csv")
])

# ---------------------------------------------
# DEFINE FEATURES
# ---------------------------------------------
feature_keywords = {
    "noise_cancellation": ["noise cancellation", "anc", "active noise"],
    "sound_quality": ["sound quality", "audio", "clarity", "bass", "treble"],
    "comfort": ["comfort", "comfortable", "wearing", "fit", "ear cups"],
    "battery": ["battery", "charge", "charging", "battery life"],
    "build": ["build", "material", "durable", "design", "headband"],
    "price": ["price", "expensive", "worth", "overpriced", "value"]
}

# ---------------------------------------------
# SENTIMENT ANALYSIS BY FEATURE
# ---------------------------------------------
def compute_feature_sentiment(df, name):
    df = df.copy()
    df['sentiment'] = df['cleaned_comment'].apply(lambda text: TextBlob(str(text)).sentiment.polarity)
    for feature in feature_keywords:
        df[feature] = df['cleaned_comment'].apply(
            lambda text: any(re.search(rf"\b{k}\b", str(text).lower()) for k in feature_keywords[feature])
        )
    result = {feature: df[df[feature]]['sentiment'].mean() for feature in feature_keywords}
    return pd.DataFrame.from_dict(result, orient='index', columns=[name])

sent_airpods = compute_feature_sentiment(df_airpods, "AirPods Max")
sent_sony = compute_feature_sentiment(df_sony, "Sony XM5")
sent_senn = compute_feature_sentiment(df_senn, "Momentum 4")

sentiment_combined = pd.concat([sent_airpods, sent_sony, sent_senn], axis=1).sort_index()

# ---------------------------------------------
# FREQUENCY ANALYSIS BY FEATURE (optional)
# ---------------------------------------------
def compute_feature_frequency(df, name):
    df = df.copy()
    counts = {}
    for feature in feature_keywords:
        counts[feature] = df['cleaned_comment'].apply(
            lambda text: any(re.search(rf"\b{k}\b", str(text).lower()) for k in feature_keywords[feature])
        ).sum()
    return pd.DataFrame.from_dict({name: counts})

# ---------------------------------------------
# GAP ANALYSIS
# ---------------------------------------------
gap_df = sentiment_combined.copy()
gap_df["CompetitorAvg"] = gap_df[["Sony XM5", "Momentum 4"]].mean(axis=1)
gap_df["Gap_vs_Competitors"] = gap_df["CompetitorAvg"] - gap_df["AirPods Max"]
gap_df["Underperforming"] = gap_df["Gap_vs_Competitors"] > 0.2

# Price-to-performance (P2P)
price_map = {"AirPods Max": 549, "Sony XM5": 399, "Momentum 4": 379}
for brand in price_map:
    gap_df[f"{brand}_P2P"] = gap_df[brand] / price_map[brand]

# ---------------------------------------------
# FINAL GAP ANALYSIS TABLE
# ---------------------------------------------
gap_output = gap_df.sort_values("Gap_vs_Competitors", ascending=False)

print("\n=== GAP ANALYSIS TABLE ===")
display(gap_output)

# ---------------------------------------------
# LIST UNDERPERFORMING FEATURES
# ---------------------------------------------
underperforming_features = gap_output[gap_output["Underperforming"]].index.tolist()
print("\n=== UNDERPERFORMING FEATURES (AirPods Max vs Competitors) ===")
for feature in underperforming_features:
    print("-", feature)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# === GAP ANALYSIS TABLE ===
#                     AirPods Max  Sony XM5  Momentum 4  CompetitorAvg  \
# price                  0.119971  0.182845    0.175495       0.179170
# battery                0.141069  0.199425    0.161048       0.180237
# sound_quality          0.172110  0.187758    0.226081       0.206919
# build                  0.116800  0.130130    0.117206       0.123668
# comfort                0.223477  0.206079    0.239511       0.222795
# noise_cancellation     0.256006  0.217378    0.218581       0.217979
#
#                     Gap_vs_Competitors  Underperforming  AirPods Max_P2P  \
# price                         0.059199            False         0.000219
# battery                       0.039167            False         0.000257
# sound_quality                 0.034809            False         0.000313
# build                         0.006867            False         0.000213
# comfort                      -0.000682            False         0.000407
# noise_cancellation           -0.038026            False         0.000466
#
#                     Sony XM5_P2P  Momentum 4_P2P
# price                   0.000458        0.000463
# battery                 0.000500        0.000425
# sound_quality           0.000471        0.000597
# build                   0.000326        0.000309
# comfort                 0.000516        0.000632
# noise_cancellation      0.000545        0.000577
# === UNDERPERFORMING FEATURES (AirPods Max vs Competitors) ===

# %%
# ---------------------------------------------
# STEP 0: SETUP
# ---------------------------------------------
import pandas as pd
import numpy as np
import nltk
import string
import openai
from nltk import word_tokenize, pos_tag
from textblob import TextBlob
import matplotlib.pyplot as plt

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
from nltk.corpus import stopwords

# Set OpenAI API key
with open("/content/drive/MyDrive/Colab/DAI_AID/keys/openai_key.txt") as f:
    openai.api_key = f.read().strip()

# ---------------------------------------------
# STEP 1: CONFIG
# ---------------------------------------------
base_dir = "/content/drive/MyDrive/Colab/DAI_AID/extracted_data/cleaned_data"
files = [
    "airpodsmax_youtube_cleaned.csv",
    "sony_xm5_youtube_cleaned.csv",
    "sennheiser_momentum4_youtube_cleaned.csv",
    "airpodsmax_reddit_cleaned.csv",
    "sony_xm5_reddit_cleaned.csv",
    "sennheiser_momentum4_reddit_cleaned.csv",
]

filename_to_product = {
    "airpodsmax_youtube_cleaned.csv": "AirPods Max",
    "sony_xm5_youtube_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_youtube_cleaned.csv": "Momentum 4",
    "airpodsmax_reddit_cleaned.csv": "AirPods Max",
    "sony_xm5_reddit_cleaned.csv": "Sony XM5",
    "sennheiser_momentum4_reddit_cleaned.csv": "Momentum 4",
}

valid_specs = {
    "battery", "noise", "cancellation", "comfort", "sound", "fit", "build", "design",
    "durability", "case", "controls", "bluetooth", "microphone", "charging", "portability",
    "volume", "latency", "app", "touch", "connectivity", "price", "weight"
}

noise = set(stopwords.words("english")).union(
    {"airpods", "apple", "sony", "sennheiser", "bruh", "max", "xm5", "momentum", "lol", "bro"}
)

def get_sentiment(text):
    if not isinstance(text, str): return "Neutral"
    polarity = TextBlob(text).sentiment.polarity
    return "Positive" if polarity > 0.1 else "Negative" if polarity < -0.1 else "Neutral"

def extract_keywords(text):
    if not isinstance(text, str):
        return []
    tokens = word_tokenize(text.lower())
    tagged = pos_tag(tokens)
    return [w for w, t in tagged if t.startswith("NN") and w not in noise and w not in string.punctuation]

# ---------------------------------------------
# STEP 2: LOAD + PROCESS FILES
# ---------------------------------------------
all_rows = []
for file in files:
    path = f"{base_dir}/{file}"
    df = pd.read_csv(path)
    if 'cleaned_comment' not in df.columns:
        print(f"Skipping {file}")
        continue
    for _, row in df.iterrows():
        sent = get_sentiment(row['cleaned_comment'])
        kws = extract_keywords(row['cleaned_comment'])
        all_rows.append({
            "filename": file,
            "product": filename_to_product[file],
            "comment": row['cleaned_comment'],
            "sentiment": sent,
            "keywords": kws
        })

df_results = pd.DataFrame(all_rows)
df_results["sentiment_score"] = df_results["sentiment"].map({"Positive": 1, "Neutral": 0, "Negative": -1})

# ---------------------------------------------
# STEP 3: GAP ANALYSIS
# ---------------------------------------------
df_exploded = df_results.explode("keywords")
df_exploded["keywords"] = df_exploded["keywords"].str.strip().str.lower()
df_specs = df_exploded[df_exploded["keywords"].isin(valid_specs)].copy()

pivot_df = df_specs.groupby(["keywords", "product"])["sentiment_score"].mean().reset_index()
pivot_table = pivot_df.pivot(index="keywords", columns="product", values="sentiment_score").fillna(0)

pivot_table["Gap_vs_Competitors"] = (
    pivot_table[["Sony XM5", "Momentum 4"]].mean(axis=1) - pivot_table["AirPods Max"]
)
pivot_table["Underperforming"] = pivot_table["Gap_vs_Competitors"] > 0.2

# Display gap table
gap_cols = [
    "AirPods Max", "Sony XM5", "Momentum 4",
    "Gap_vs_Competitors", "Underperforming"
]
print("\n=== GAP ANALYSIS TABLE ===")
display(pivot_table[gap_cols].sort_values("Gap_vs_Competitors", ascending=False))

# ---------------------------------------------
# STEP 4: DESIGN OPPORTUNITY INSIGHTS (TOP GAP ONLY)
# ---------------------------------------------
N = 5  # number of top features to analyze
top_underperf = (
    pivot_table[pivot_table["Underperforming"]]
    .sort_values("Gap_vs_Competitors", ascending=False)
    .head(N)
    .index
    .tolist()
)

comments_by_feature = df_specs[
    (df_specs["product"] == "AirPods Max") &
    (df_specs["keywords"].isin(top_underperf))
].groupby("keywords")["comment"].apply(lambda x: "\n".join(x.dropna().unique()[:10]))

def gpt_design_opportunity(feature, comments):
    prompt = f"""
You are a product strategist. Users gave negative feedback on the **"{feature}"** of the AirPods Max.
Here are sample complaints:
{comments}

Based on these:
1. Identify specific issues
2. Translate to measurable design specs
3. Suggest improvements
4. Estimate potential impact (sales, brand, ROI)
5. List all insights clearly in bullet points.
"""
    try:
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# Generate insights
#print(f"\n=== GPT DESIGN OPPORTUNITY ANALYSIS (TOP {N} FEATURES) ===")
#for feature, sample_comments in comments_by_feature.items():
 #   print(f"\n\n===== DESIGN OPPORTUNITY: {feature.upper()} =====")
  #  print(gpt_design_opportunity(feature, sample_comments))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# === GAP ANALYSIS TABLE ===
# product       AirPods Max  Sony XM5  Momentum 4  Gap_vs_Competitors  \
# keywords
# microphone       0.333333  0.473684    0.875000            0.341009
# fit              0.571429  0.851852    0.846154            0.277574
# build            0.529412  0.800000    0.777778            0.259477
# latency          0.161290  0.318182    0.500000            0.247801
# comfort          0.555556  0.742857    0.782609            0.207177
# case             0.403587  0.471649    0.620253            0.142364
# battery          0.475410  0.703448    0.523077            0.137853
# weight           0.378378  0.666667    0.363636            0.136773
# price            0.481928  0.579545    0.592105            0.103898
# portability      0.714286  0.633333    1.000000            0.102381
# volume           0.433333  0.513889    0.458333            0.052778
# design           0.410714  0.428571    0.468085            0.037614
# app              0.384615  0.367347    0.464286            0.031201
# noise            0.596330  0.524621    0.676471            0.004216
# sound            0.840909  0.790274    0.857143           -0.017201
# connectivity     0.416667  0.454545    0.300000           -0.039394
# cancellation     0.791667  0.554688    0.923077           -0.052784
# charging         1.000000  0.833333    1.000000           -0.083333
# controls         0.400000  0.257143    0.352941           -0.094958
# touch            0.600000  0.512195    0.360000           -0.163902
# durability       0.750000  0.567568    0.571429           -0.180502
# bluetooth        0.550000  0.452381    0.260870           -0.193375
#
# product       Underperforming
# keywords
# microphone               True
# fit                      True
# build                    True
# latency                  True
# comfort                  True
# case                    False
# battery                 False
# weight                  False
# price                   False
# portability             False
# volume                  False
# design                  False
# app                     False
# noise                   False
# sound                   False
# connectivity            False
# cancellation            False
# charging                False
# controls                False
# touch                   False
# durability              False
# bluetooth               False
